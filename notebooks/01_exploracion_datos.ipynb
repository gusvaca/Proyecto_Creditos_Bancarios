# %% [markdown]
# # 1. Exploración de Datos
#
# Carga y análisis exploratorio inicial del dataset de créditos bancarios.

# %%
import pandas as pd
import numpy as np

# Cargar datos
df = pd.read_csv('../data/creditos_bancarios.csv')

# %%
# Información general del dataset
print('Forma del dataset:', df.shape)
print('\nTipos de datos:')
print(df.dtypes)
print('\nValores faltantes:')
print(df.isnull().sum())
