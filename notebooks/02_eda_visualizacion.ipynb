# %% [markdown]
# # 2. Análisis Exploratorio de Datos (EDA) y Visualización
#
# Análisis detallado y visualización de patrones en el dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Cargar datos
df = pd.read_csv('../data/creditos_bancarios.csv')

# %%
# Estadísticas descriptivas
df.describe()
